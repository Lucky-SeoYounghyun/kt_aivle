# %% [markdown]
# # 와인 품질 예측하기

# %% [markdown]
# ![](https://labelyourdata.com/img/article-illustrations/ml_essential_tool.jpg)

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Input
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/winequality-white.csv"
data = pd.read_csv(path)
data['quality'] = np.where(data['quality'] == 3, 4, np.where(data['quality'] == 9, 8, data['quality']))
data['quality'] = data['quality'] - 4
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        2
# 1      9.5        2
# 2     10.1        2
# 3      9.9        2
# 4      9.9        2

# %% [markdown]
# * 범주가 5개 입니다.
#     * 0 - 최하  ~  4 - 최상

# %%
data['quality'].value_counts()
# Out:
# quality
# 2    2198
# 1    1457
# 3     880
# 0     183
# 4     180
# Name: count, dtype: int64

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# ### (1) 데이터 준비
# * y에 대한 전처리 : 위에서 이미 0 ~ 4로 범주를 맞췄습니다.
# * x, y 나누기

# %%
target = 'quality'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (2) 데이터 분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size= .3, random_state = 20)

# %% [markdown]
# ### (3) 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.모델링
#
# 최소 3개 이상의 모델을 생성하고 성능을 비교하시오.

# %% [markdown]
# ### (1) 모델1

# %%
model = Sequential([Input(shape = (11,)),
                    Dense(10, activation='relu'),
                    Dense(10, activation='relu'),
                    Dense(5, activation='relu'),
                    Dense(5, activation='relu'),
                    Dense(5, activation='softmax')]) # 다중분류는 softmax

# %%
model.compile( optimizer = Adam(learning_rate = 0.01), loss = 'sparse_categotical_crossentropy')
result = model.fit(x_train, y_train, validation_split = .2, echo = )

# %%
-

# %% [markdown]
# ### (2) 모델2

# %% [markdown]
# ### (3) 모델3
