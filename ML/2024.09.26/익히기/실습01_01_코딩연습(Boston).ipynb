# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/ml_python.png' width=600/></center>

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/boston.png?raw=true" width=800 align="left"/>

# %% [markdown]
# # 실습 내용
#
# - 머신러닝 모델링을 위한 코딩은 무조건 할 수 있어야 합니다.
# - 코딩 내용을 자세히 알지 못해도 무작정 코딩을 진행해봅니다.
# - Boston 데이터를 대상으로 모델링해서 집값을 예측해 봅니다.
# - LinearRegression 알고리즘을 사용합니다.

# %% [markdown]
# # 1.환경 준비
#
# - 기본 **라이브러리**와 대상 **데이터**를 가져와 이후 과정을 준비합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_11.png?raw=true" width=700 align="left"/>

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format = 'retina'

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/Jangrae/csv/master/boston.csv'
data = pd.read_csv(path)

# %% [markdown]
# # 2.데이터 이해
#
# - 분석할 데이터를 **충분히 이해**할 수 있도록 다양한 **탐색** 과정을 수행합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_12.png?raw=true" width=700 align="left"/>

# %%
# 상위 몇 개 행 확인
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# **데이터 설명**
#
# - crim: 자치시(Town)별 1인당 범죄율
# - zn: 25,000 평방피트를 초과하는 거주지역 비율
# - indus: 비소매상업지역이 점유하고 있는 토지 비율
# - chas: 찰스강에 대한 더미 변수 (= 1 강 경계에 위치; 0 나머지)
# - nox: 10ppm당 농축 일산화질소
# - rm: 주택 1가구당 평균 방 개수
# - age: 1940년 이전에 건축된 소유주택 비율
# - dis: 5개 보스턴 직업센터까지 접근성 지수
# - rad: 방사형 도로까지의 접근성 지수
# - tax: 10,000달러 당 재산세율
# - ptratio: 자치시(Town)별 학생/교사 비율
# - black: 1000(Bk - 0.63)^2, 여기서 Bk는 자치시별 흑인의 비율을 의미
# - lstat: 모집단 하위 계층의 비율(%)
# - medv: 본인 소유 주택가격(중앙값) (단위:$1,000)

# %%
# 하위 몇 개 행 확인
data.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#       black  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
# 변수 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
# 기술통계 확인
data.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
# 상관관계 확인
tmp = data.corr(numeric_only=True)
tmp.style.background_gradient()
# Out:
# <style type="text/css">
# #T_d12c9_row0_col0, #T_d12c9_row1_col1, #T_d12c9_row2_col2, #T_d12c9_row3_col3, #T_d12c9_row4_col4, #T_d12c9_row5_col5, #T_d12c9_row6_col6, #T_d12c9_row7_col7, #T_d12c9_row8_col8, #T_d12c9_row9_col9, #T_d12c9_row10_col10, #T_d12c9_row11_col11, #T_d12c9_row12_col12, #T_d12c9_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d12c9_row0_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_d12c9_row0_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_d12c9_row0_col3, #T_d12c9_row12_col11 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_d12c9_row0_col4 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_d12c9_row0_col5 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_d12c9_row0_col6, #T_d12c9_row1_col13 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_d12c9_row0_col7, #T_d12c9_row11_col4, #T_d12c9_row11_col10 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_d12c9_row0_col8 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_d12c9_row0_col9, #T_d12c9_row2_col8, #T_d12c9_row8_col0 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_d12c9_row0_col10 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_d12c9_row0_col11, #T_d12c9_row13_col9 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_d12c9_row0_col12 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_d12c9_row0_col13, #T_d12c9_row9_col5 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_d12c9_row1_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_d12c9_row1_col2, #T_d12c9_row1_col6, #T_d12c9_row5_col10, #T_d12c9_row8_col3, #T_d12c9_row12_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_d12c9_row1_col3 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_d12c9_row1_col4, #T_d12c9_row1_col9 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_d12c9_row1_col5, #T_d12c9_row2_col0 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_d12c9_row8_col6 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_d12c9_row8_col7, #T_d12c9_row9_col13, #T_d12c9_row12_col7 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_d12c9_row8_col9 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_d12c9_row8_col10 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_d12c9_row8_col12 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_d12c9_row8_col13, #T_d12c9_row11_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_d12c9_row9_col0, #T_d12c9_row12_col9 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T

# %%
plt.figure(figsize=(10, 10)) 
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap = 'Blues', cbar = False, square = True, fmt = '.5f', annot_kws={'size' : 8})
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# # 3.데이터 준비
#
# - **전처리** 과정을 통해 머신러닝 알고리즘에 사용할 수 있는 형태의 데이터를 준비합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_13.png?raw=true" width=700 align="left"/>

# %% [markdown]
# **1) x, y 분리**
#
# - 우선 target 변수를 명확히 지정합니다.
# - target을 제외한 나머지 변수들 데이터는 x로 선언합니다.
# - target 변수 데이터는 y로 선언합니다.
# - 이 결과로 만들어진 x는 데이터프레임, y는 시리즈가 됩니다.
# - 이후 모든 작업은 x, y를 대상으로 진행합니다.

# %%
data.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
# target 확인

target = 'medv'
# 데이터 분리

x = data.drop(target, axis = 1) # or x = data.drop(columns=target)
y = data.loc[:, target]

# %% [markdown]
# **2) 학습용, 평가용 데이터 분리**
#
# - 학습용, 평가용 데이터를 적절한 비율로 분리합니다.
# - 반복 실행 시 동일한 결과를 얻기 위해 random_state 옵션을 지정합니다.

# %%
# 모듈 불러오기

from sklearn.model_selection import train_test_split
# 7:3으로 분리

x_train, x_test, y_train, y_test = train_test_split(x ,y, test_size=0.3, random_state=1)

# %% [markdown]
# # 4.모델링
#
# - 본격적으로 모델을 **선언**하고 **학습**하고 **평가**하는 과정을 진행합니다.
# - 우선 **회귀** 문제인지 **분류** 문제인지 명확히 구분합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_14.png?raw=true" width=700 align="left"/>

# %% [markdown]
# **1) 모델링**
#
# - 회귀 문제 인가요? 분류 문제인가요?
# - 회귀인지 분류인지에 따라 사용할 알고리즘과 평가 방법이 달라집니다.
# - 우선 다음 알고리즘과 평가 방법을 사용합니다.
#     - 알고리즘: LinearRegression
#     - 평가방법: mean_absolute_error

# %%
# 1단계: 불러오기

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
# 2단계: 선언하기

model = LinearRegression()

# %%
# 3단계: 학습하기

model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# 4단계: 예측하기

y_pred = model.predict(x_test)

# %%
# 5단계: 평가하기

mean_absolute_error(y_test, y_pred)
# Out:
# 3.3446655035987605

# %%
y_mean = [y_train.mean()] * len(y_test)

mean_absolute_error(y_test, y_mean)

# 회구모델의 기준은 평균임
# Out:
# 6.7759143621766285

# %% [markdown]
# **2) 예측값과 실젯값 시각화 비교**

# %%
# 예측값과 실젯값 시각화 비교

print('실제값 : ', y_test.values[:10])
print('예측값 : ', y_pred[:10])
# Out:
# 실제값 :  [28.2 23.9 16.6 22.  20.8 23.  27.9 14.5 21.5 22.6]
# 예측값 :  [32.3914647  27.94401279 17.83762764 21.66941388 18.93639614 20.01995795
#  32.63414961 17.86179976 24.73211676 26.77346826]

# %%
plt.plot(y_test.values)
plt.plot(y_pred)
plt.legend(['Actual', 'Predicted'])
plt.show()
