# %%
import torch

x_train = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]])
y_train = torch.FloatTensor([[1], [0], [0], [1]])
w_h = torch.randn([2, 3], requires_grad = True)
b_h = torch.randn([3], requires_grad = True)
w_o = torch.randn([3, 1], requires_grad = True)
b_o = torch.randn([1], requires_grad = True)

optimizer = torch.optim.SGD([w_h, b_h, w_o, b_o], lr = 0.01)

# [ 딥러닝 1단계 ] 모델을 만든다. Model setup
def H(x) :
  h1 = torch.sigmoid(torch.matmul(x,w_h) + b_h)
  model = torch.sigmoid(torch.matmul(h1,w_o) + b_o)
  return model

# [ 딥러닝 2단계 ] 학습을 시킨다. Traning
for iter in range(200000):
  cost = torch.mean((-1)*y_train*torch.log(H(x_train))+(-1)*(1-y_train)*torch.log(1-H(x_train)))
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()
  if iter % 10000 == 0 : print('[Iteration]', iter, '[cost]', cost.detach().item())

# [ 딥러닝 3단계 ] 추론을 수행한다. Inference

x_test = torch.FloatTensor([[7, 1]])

model_result = H(x_train)
print(model_result)

# model_result = H(x_text)
# print('Model Inference with [7,1] : ', model_result.detach().item())
# if model_result.detach().item() < 0.5:
#   print('F')
# else:
#   print('T')
# Out:
# [Iteration] 0 [cost] 0.7015409469604492
# [Iteration] 10000 [cost] 0.6878899335861206
# [Iteration] 20000 [cost] 0.5966278910636902
# [Iteration] 30000 [cost] 0.17103657126426697
# [Iteration] 40000 [cost] 0.06225934997200966
# [Iteration] 50000 [cost] 0.03518041595816612
# [Iteration] 60000 [cost] 0.023986980319023132
# [Iteration] 70000 [cost] 0.018032392486929893
# [Iteration] 80000 [cost] 0.014378886669874191
# [Iteration] 90000 [cost] 0.01192298624664545
# [Iteration] 100000 [cost] 0.010165284387767315
# [Iteration] 110000 [cost] 0.00884950254112482
# [Iteration] 120000 [cost] 0.007828043773770332
# [Iteration] 130000 [cost] 0.007013536989688873
# [Iteration] 140000 [cost] 0.006348771043121815
# [Iteration] 150000 [cost] 0.005797745659947395
# [Iteration] 160000 [cost] 0.0053320880979299545
# [Iteration] 170000 [cost] 0.004935592412948608
# [Iteration] 180000 [cost] 0.004592224024236202
# [Iteration] 190000 [cost] 0.00429352093487978
# tensor([[0.9955],
#         [0.0030],
#         [0.0050],
#         [0.9964]], grad_fn=<SigmoidBackward0>)
