# %%
def create_hello_files(name, count):
    for num in range(1, count + 1):
        filename = f"{name}_{num}.txt"
        with open(filename, "w") as file:
            file.write("hello")
        print(f"{filename} created.")

create_hello_files("example", 5)
